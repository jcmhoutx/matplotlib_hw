# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Read the City and Ride Data
city = pd.read_csv("Data/city_data.csv")
ride = pd.read_csv("Data/ride_data.csv")

# %%
# Combine the data into a single dataset
city_ride = pd.merge(city, ride, on="city")

# Assign numerical amounts based on city type for use in plot colorization
ct = city_ride["type"].tolist()
size_num = []
idx = 0

for size in ct:
    if size == "Urban":
        size_num.insert(idx, 0.1)
        idx += 1
    elif size == "Suburban":
        size_num.insert(idx, 0.5)
        idx += 1
    else:
        size_num.insert(idx, 0.9)
        idx += 1

city_ride["size_value"] = pd.Series(size_num)
        
# Display the data table for preview
city_ride.head()
# Out:
#           city  driver_count   type                 date   fare  \
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00
#
#          ride_id  size_value
# 0  5628545007794         0.1
# 1   910050116494         0.1
# 2   820639054416         0.1
# 3  9554935945413         0.1
# 4   720020655850         0.1

# %%
# Obtain the x and y coordinates for each of the three city types
city_groups = city_ride.groupby(["city"])
num_rides = city_groups["date"].count()
average_fare = city_groups["fare"].mean()
driver_count = city_groups["driver_count"].first()
city_type = city_groups["type"].first()
city_size = city_groups["size_value"].first()

# # Convert to DataFrame
city_ride_df = pd.DataFrame({"Number of Rides":num_rides, "Average Fare":average_fare, "Driver Count":driver_count,
                            "Type":city_type, "Value":city_size}).groupby(["city"])
city_ride_df.head()
# Out:
#                       Number of Rides  Average Fare  Driver Count      Type  \
# city
# Amandaburgh                        18     24.641667            12     Urban
# Barajasview                        22     25.332273            26     Urban
# Barronchester                      16     36.422500            11  Suburban
# Bethanyland                        18     32.956111            22  Suburban
# Bradshawfurt                       10     40.064000             7     Rural
# Brandonfort                        19     35.437368            10  Suburban
# Carriemouth                        27     28.314444            52     Urban
# Christopherfurt                    27     24.501852            41     Urban
# Colemanland                        22     30.894545            23  Suburban
# Davidfurt                          17     31.995882            23  Suburban
# Deanville                          19     25.842632            49     Urban
# ...

# %%
# Build the scatter plots for each city type
cr_reset = pd.DataFrame({"Number of Rides":num_rides, "Average Fare":average_fare, "Driver Count":driver_count,
                            "City Type":city_type, "Size Value":city_size})
cr_reset.reset_index()

x = cr_reset["Number of Rides"]
y = cr_reset["Average Fare"]
s = cr_reset["Driver Count"]

colors = {0.1:"xkcd:orangeish", 0.5:"xkcd:light sky blue", 0.9:"xkcd:sickly yellow"}

cr_reset = pd.DataFrame({"Number of Rides":num_rides, "Average Fare":average_fare, "Driver Count":driver_count,
                            "Type":city_type, "Value":city_size})
cr_reset.reset_index()

plt.scatter(x, y, s, c=cr_reset["Value"].map(colors), alpha=0.5)
plt.show()

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure
